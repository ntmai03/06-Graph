# %% [markdown]
# # Import library

# %%
# Dataframe manipulation
import numpy as np
import pandas as pd
import math

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set(style = 'whitegrid',context = 'notebook')

# Preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Imputer, LabelEncoder

# Modelling Helpers:
from sklearn.preprocessing import Imputer, Normalizer, scale
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score, ShuffleSplit, cross_validate
from sklearn import model_selection
from sklearn.model_selection import train_test_split

# Classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from lightgbm import LGBMClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
# Evaluation metrics for Classification
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, classification_report, roc_auc_score, roc_curve, precision_recall_curve, average_precision_score

# Regression
from sklearn.linear_model import LinearRegression,Ridge,Lasso,RidgeCV,ElasticNet,LogisticRegression
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
# Evaluation metrics for Regression 
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score, mean_absolute_error

# Configuration
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)

# Supress warnings
import warnings
warnings.filterwarnings("ignore")

print("Setup complete...")
# Out:
# Setup complete...

# %% [markdown]
# # Common function

# %%
def Check_Missing_Data(df):    
    # count all missing values of each column
    total = df.isnull().sum().sort_values(ascending=False)
    # calculate percentage of null values for each column
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %% [markdown]
# # Import dataset

# %%
# load dataset
df = pd.read_csv('London_listings.csv')
print(df.shape)
df.head()
# Out:
# (77096, 96)
#       id                         listing_url       scrape_id last_scraped                                   name                                            summary                                              space                                        description experiences_offered                              neighborhood_overview                                              notes                                            transit                                             access  \
# 0   9554   https://www.airbnb.com/rooms/9554  20181207034825   2018-12-07     Cozy, 3 minutes to Piccadilly Line  PLEASE CONTACT ME BEFORE BOOKING Homely apartm...  Hello people, This is a bright, comfortable ro...  PLEASE CONTACT ME BEFORE BOOKING Homely apartm...                none                                Details to follow..                                                NaN            details to follow when i get a chance..  Kitchen, small dining / smoking room (if you s...
# 1  11076  https://www.airbnb.com/rooms/11076  20181207034825   2018-12-07                          The Sanctuary  The room has a double bed and a single foldawa...  This Listing is for The Sanctury The accommoda...  The room has a double bed and a single foldawa...                none  Ealing Broadway, as short walk from our place ...                                                NaN  extemely good transport links to central londo...                  Huge family kitchen and good wifi
# 2  13913  https://www.airbnb.com/rooms/13913  20181207034825   2018-12-07    Holiday London DB Room Let-on going  My bright double bedroom with a large window h...  Hello Everyone, I'm offering my lovely double ...  My bright double bedroom with a large window h...            business  Finsbury Park is a friendly melting pot commun...  For art lovers I can give guest my Tate Member...  The flat only a 10 minute walk to Finsbury Par...  Guest will have access to the self catering ki...
# 3  17402  https://www.airbnb.com/rooms/17402  20181207034825   2018-12-07  Superb 3-Bed/2 Bath & Wifi: Trendy W1  Open from June 2018 after a 3-year break, we a...  Ready again from June 2018 for bookings after ...  Open from June 2018 after a 3-year break, we a...                none  Location, location, location! You won't find b...  This property has new flooring throughout. Gue...  You can walk to tourist London or take numerou...            Full use of whole independent apartment
# 4  24328  https://www.airbnb.com/rooms/24328  20181207034825   2018-12-07    Battersea 2 bedroom house & parking  Artist house, high ceiling bedrooms, private p...  - End of terrace two bedroom house close to So...  Artist house, high ceiling bedrooms, private p...              family  - Battersea is a quiet family area, easy acces...  - Please have a profile or tell us more about ...  - 5 mins walk to Battersea Park, 15 mins walk ...  - there is a communal garden in our complex - ...
#
#                                          interaction                                        house_rules  thumbnail_url  medium_url                                        picture_url  xl_picture_url  host_id                                 host_url host_name  host_since                    host_location                                         host_about  host_response_time host_response_rate  host_acceptance_rate host_is_superhost                                 host_thumbnail_url  \
# 0  Depends on what else I have on.. It is always ...  If you smoke, please do so only in the little ...            NaN         NaN  https://a0.muscache.com/im/pictures/77912984/a...             NaN    31655  https://www.airbnb.com/users/show/31655       Guy  2009-08-14  London, England, United Kingdom  Please contact me before booking! Please see d...  within a few hours               100%                   NaN                 t  https://a0.muscache.com/im/pictures/9cae5e2c-3...
# 1  We give everyone a great welcome and make sure...                We don't allow alcohol or takeaways            NaN         NaN  https://a0.muscache.com/im/pictures/a0f4c78a-6...             NaN    40471  https://www.airbnb.com/users/show/40471      Rosa  2009-09-22  London, England, United Kingdom  Hi, I'm Rosa, I'm one of the owners of the At-...        within a day                67%                   NaN                 f  https://a0.muscache.com/im/users/40471/profile...
# 2  I like to have little chats with my guest over...  I'm an artist and have my artwork up on the wa...            NaN         NaN  https://a0.muscache.com/im/pictures/985879/b06...             NaN    54730  https://www.airbnb.com/users/show/54730     Alina  2009-11-16  London, England, United Kingdom  I am a Multi-Media Visual Artist and Creative ...        within a day                67%                   NaN                 f  https://a0.muscache.com/im/users/54730/profile...
# 3  Always available by email or phone (before, du...  The apartment benefits from new flooring throu...            NaN         NaN  https://a0.muscache.com/im/pictures/5673eb4f-a...             NaN    67564  https://www.airbnb.com/users/show/67564       Liz  2010-01-04  London, England, United Kingdom  We are Liz and Jack.  We manage a number of ho...      within an hour                91%                   NaN                 t  https://a0.muscache.com/im/users/67564/profile...
# 4  We rent out our house only when we are away. T...  A house manual will be emailed once a booking ...            NaN         NaN  https://a0.muscache.com/im/pictures/428381/d92...             NaN    41759  https://www.airbnb.com/users/show/41759       Joe  2009-09-28         Florence, Tuscany, Italy  I've been using Airbnb for a while now, both a...                 NaN                NaN                   NaN                 f  https://a0.muscache.com/im/users/41759/profile...
#
#                                     host_picture_url host_neighbourhood  host_listings_count  host_total_listings_count                                 host_verifications host_has_profile_pic host_identity_verified                                     street    neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed       city           state   zipcode  market             smart_location country_code         country   latitude  longitude is_location_exact property_type  \
# 0  https://a0.muscache.com/im/pictures/9cae5e2c-3...     LB of Haringey                  4.0                        4.0  ['email', 'phone', 'manual_online', 'reviews',...                    t                      f                     London, United Kingdom   LB of Haringey               Haringey                           NaN     London             NaN    N8 0EY  London     London, United Kingdom           GB  United Kingdom  51.587767  -0.105666                 f     Apartment
# 1  https://a0.muscache.com/im/users/40471/profile...       LB of Ealing                  6.0                        6.0  ['email', 'phone', 'facebook', 'reviews', 'wor...                    t                      f     Ealing, Greater London, United Kingdom     LB of Ealing                 Ealing                           NaN     Ealing  Greater London     W13 8  London     Ealing, United Kingdom           GB  United Kingdom  51.515645  -0.314508                 t     Apartment
# 2  https://a0.muscache.com/im/users/54730/profile...    LB of Islington                  4.0                        4.0          ['email', 'phone', 'facebook', 'reviews']                    t                      f  Islington, Greater London, United Kingdom  LB of Islington              Islington                           NaN  Islington  Greater London      N4 3  London  Islington, United Kingdom           GB  United Kingdom  51.568017  -0.111208                 t     Apartment
# 3  https://a0.muscache.com/im/users/67564/profile...          Fitzrovia                 15.0                       15.0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t                      t          London, Fitzrovia, United Kingdom        Fitzrovia            Westminster                           NaN     London       Fitzrovia    W1T4BP  London     London, United Kingdom           GB  United Kingdom  51.520982  -0.140024                 t     Apartment
# 4  https://a0.muscache.com/im/users/41759/profile...          Battersea                  2.0                        2.0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t                      t                     London, United Kingdom        Battersea             Wandsworth                           NaN     London             NaN  SW11 5GX  London     London, United Kingdom           GB  United Kingdom  51.472981  -0.163764                 t     Townhouse
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type                                          amenities  square_feet    price weekly_price monthly_price security_deposit cleaning_fee  guests_included extra_people  minimum_nights  maximum_nights calendar_updated has_availability  availability_30  availability_60  availability_90  availability_365 calendar_last_scraped  number_of_reviews first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0     Private room             2        NaN       1.0   1.0  Real Bed  {TV,Internet,Wifi,Kitchen,"Smoking allowed",Br...          NaN   $35.00      $198.00       $788.00              NaN        $7.00                1       $15.00               1             730       a week ago                t               18               18               18               291            2018-12-07                133   2012-04-26  2018-08-13                  97.0                    10.0
# 1     Private room             2        NaN       1.0   1.0  Real Bed  {TV,"Cable TV",Internet,Wifi,Breakfast,"Pets l...          NaN   $70.00          NaN           NaN              NaN          NaN                2       $35.00               2            1125     4 months ago                t                0                0                0                 0            2018-12-07                  3   2016-04-05  2018-10-18                  90.0                     8.0
# 2     Private room             2        1.0       1.0   0.0  Real Bed  {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...        538.0   $65.00      $333.00     $1,176.00          $100.00       $15.00                1       $15.00               1              29      2 weeks ago                t               29               59               89               364            2018-12-07                 14   2010-08-18  2018-06-17                  95.0                     9.0
# 3  Entire home/apt             6        2.0       3.0   3.0  Real Bed  {TV,Wifi,Kitchen,"Paid parking off premises",E...          NaN  $300.00    $1,378.00           NaN          $350.00       $65.00                4       $10.00               3             365        yesterday                t               26               56               86               360            2018-12-07                 39   2011-03-21  2018-10-15                  93.0                    10.0
# 4  Entire home/apt             4        1.5       2.0   2.0  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...       1001.0  $150.00    $1,050.00     $3,500.00          $250.00       $70.00                2       $15.00              90              90     9 months ago                t               28               58               88               363            2018-12-07                 92   2010-11-15  2016-09-07                  98.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  review_scores_communication  review_scores_location  review_scores_value requires_license license  jurisdiction_names instant_bookable is_business_travel_ready          cancellation_policy require_guest_profile_picture require_guest_phone_verification  calculated_host_listings_count  reviews_per_month
# 0                        9.0                   10.0                         10.0                     9.0                 10.0                f     NaN                 NaN                f                        f  strict_14_with_grace_period                             t                                f                               4               1.65
# 1                        9.0                   10.0                          9.0                     9.0                  9.0                f     NaN                 NaN                t                        f  strict_14_with_grace_period                             f                                f                               6               0.09
# 2                       10.0                    9.0                         10.0                     9.0                  9.0                f     NaN                 NaN                f                        f                     moderate                             f                                f                               3               0.14
# 3                        9.0                    9.0                          9.0                    10.0                  9.0                f     NaN                 NaN                f                        f  strict_14_with_grace_period                             f                                f                              13               0.42
# 4                       10.0                   10.0                         10.0                     9.0                  9.0                f     NaN                 NaN                f                        f  strict_14_with_grace_period                             t                                t                               1               0.94

# %% [markdown]
# ### remove redundant features

# %%
remove_list = ['listing_url', 'scrape_id', 'last_scraped', 'name',       
              'interaction', 'house_rules', 'thumbnail_url', 'medium_url',
              'picture_url', 'xl_picture_url', 'host_id', 'host_url',
              'host_thumbnail_url', 'host_picture_url',       
              'host_has_profile_pic',
              'calendar_last_scraped', 
              'first_review', 'last_review',
              'requires_license', 'license', 'jurisdiction_names',
              'is_business_travel_ready',
              'require_guest_profile_picture',
              'require_guest_phone_verification']
print(len(remove_list))        # 25
selected_features = [e for e in df.columns.values if e not in remove_list]
len(selected_features)   # 70
df = df.loc[:,selected_features]
df.shape
# Out:
# 24
# (77096, 72)

# %% [markdown]
# # Fixing incorrect data

# %% [markdown]
# The incorrect data is found during exploration stage

# %% [markdown]
# ### Converting format of price

# %%
df['price'] = (df['price'].str.replace(r'[^-+\d.]','').astype(float))
df['monthly_price'] = (df['monthly_price'].str.replace(r'[^-+\d.]','').astype(float))
df['weekly_price'] = (df['weekly_price'].str.replace(r'[^-+\d.]','').astype(float))
df['extra_people'] = (df['extra_people'].str.replace(r'[^-+\d.]','').astype(float))
df['cleaning_fee'] = (df['cleaning_fee'].str.replace(r'[^-+\d.]','').astype(float))

# %% [markdown]
# ### remove rows with target variable as 0

# %%
print(df[df.price == 0].shape)
print(df[df.price > 0].shape)
# Out:
# (33, 72)
# (77063, 72)

# %%
# remove rows with price ==0
df = df.loc[df.price > 0,:]
df.shape
# Out:
# (77063, 72)

# %% [markdown]
# ### Converting numeric value from object type to numeric type

# %%
# make a list of the categorical variables that contain missing values
categorical_list = [var for var in df.columns if df[var].dtypes=='O']

# %% [markdown]
# #### Investigate frequency of labels in each variable

# %%
def analyze_frequency_labels(df,var):
    df = df.copy()
    tmp = df.groupby(var)['id'].count()/len(df)
    return tmp

for var in categorical_list:
    print(analyze_frequency_labels(df,var))
    print()
# Out:
# summary
#           Curious to experience what living in central London means? This is your ideal choice! Comfortable and big bedroom located in a 4 floors house where people with different nationalities and cultures magically mix and live together. 5 min/tube                                                                                                                                                                                                                                                            0.000013
#         Modern, newly renovated 2 bedroom flat with West facing balcony & free secure off-street parking just by Newington Green.  With great transport links to trendy Shoreditch, King's Cross/ St Pancras and just about anywhere in Central London.                                                                                                                                                                                                                                                               0.000013
#         Nestled in heart of Islington and only 15 mins from central London.  Our gorgeous modern well furnished flat with all mod cons offers great views from the balcony is located near fantastic shops and amenities, offering an authentic village feel.                                                                                                                                                                                                                                                         0.000013
#         This is a two double bedroom apartment in the heart of Barnsbury (Islington Borough), N1. It is a quiet residential area surrounded by Victorian and Georgian streets.                                                                                                                                                                                                                                                                                                                                        0.000013
#        Situated 5 mins walk to trendy Bermondsey St. This appartment is brand new with stylish double bedroom with own bathroom in a shared flat. Spacious with large wardrobe. Other areas that are shared include large kitchen and living area.                                                                                                                                                                                                                                                                    0.000013
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 저희 집은 Hampstead Theatre 근처에 있습니다. 저희 집의 장점은 편안한 침대입니다. 저희 집은 나홀로 여행족에 적합합니다.                                                                                                                                                                                                                                                                                                                                                                                                                                          0.000013
# 한국분들 한국어로 문의주셔도 됩니다~^^ Check in might be arranged before 6PM. Discussion required Hi! I invite you to my small and cozy house. Although in an old building, I always keep my place clean and tidy. So this is suitable for young travellers want a private room with a hostel dormitory price! Importantly, I provide everything our young travellers need! (Towels, Fast WIFI, UK adaptor, Shampoo, Shower gel, Hairdryer, Roll paper) Water purifier in the kitchen to drink fresh clean water for free~!!          0.000013
# 한인 민박도 함께 운영하고 있음.  한식조식 제공(오전 개인 취사 금지)                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0.000013
# ️￫ Four bedroom house has 3 double beds, 1 single bed, sleeps up to 7 people. ￫ Ideal for a large family, couples or group of friends traveling to London ￫ Well maintained private back garden and FREE permit parking. ️￫ 2-min walk to Cyprus DLR Train, Zone 3.  Westminster within 30 mins ￫ Fresh linen, towels, toiletries & essentials provided. ￫ Fully equipped kitchen. ￫ Professionally cleaned every time. ￫ FREE unlimited 50Mbs Fibre WiFi, TV with Netflix. ￫ FREE  Tea, Instant Coffee and Sugar.    0.000013
# ﾛﾝﾄﾞﾝ市内の西部(ｾﾝﾄﾗﾙ線､ｼｪﾊﾟｰｽﾞ･ﾌﾞｯｼｭ駅より徒歩2分､ｿﾞｰﾝ2)に位置する静かで清潔､小さな庭付きのお家で､ﾌﾗﾝｽ人の主人と暮らしています｡ｵｯｸｽﾌｫｰﾄﾞ･ｻｰｶｽ駅､ﾋﾟｶﾃﾞﾘｰ･ｻｰｶｽ駅まで地下鉄で約15-20分と便利で､家から徒歩5分には､大型ｼｮｯﾋﾟﾝｸﾞｾﾝﾀｰのｳｪｽﾄﾌｨｰﾙﾄﾞ､高級ｽｰﾊﾟｰのｳｪｲﾄﾛｰｽﾞ､ｼｪﾊﾟｰｽﾞﾌﾞｯｼｭﾏｰｹｯﾄ､ﾚｽﾄﾗﾝやｶﾌｪ等もあります｡ 小さなｼﾝｸﾞﾙﾙｰﾑで､ﾊﾞｽﾙｰﾑ､ｷｯﾁﾝ､ﾀﾞｲﾆﾝｸﾞﾙｰﾑは共用になります｡ その他､ご質問ございましたら､お気軽にお問い合わせ下さいませ｡                                                                                                                                                                                                               0.000013
# Name: id, Length: 69093, dtype: float64
#
# space
#     A cosy 2 bed flat in Dalston, on a top floor of a gated new build.     The main room has a queen size bed and the other room has a double size futon bed with an added mattress on top. The photos speak for themselves, but I have had people requesting separate/single beds.        Finally please note as most places in England my flat sadly hasn't got a lift, so be prepared for some exercise and 3 sets of stairs!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# 한인 민박도 함께 운영하고 있음.  한식조식 제공(오전 개인 취사 금지) 한식 조식 제공(오전 개인 취사 금지) 한인 민박도 함께 운영하고 있음.  더블 1에 스페어 배드 추가 가능 ( 10 파운드 추가) 베드룸 주방 겸 식탁 런던아이, 빅밴 도보 (10분), 워터루역에서 2분, 램버스 노스 역에서 1분 거리. 집앞에 작은 공원과 놀이터 있음. 길건너에 테스코 와 코스타 커피솦. 그리고 스트릿   푸드마켓, 작은 공원과 펍 & 레스토랑 등등 기차. 전철. 다수의 버스                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.000013
# ️￫ Four bedroom house has 3 double beds, 1 single bed, sleeps up to 7 people. ￫ Ideal for a large family, couples or group of friends traveling to London ￫ Well maintained private back garden and FREE permit parking. ️￫ 2-min walk to Cyprus DLR Train, Zone 3.  Westminster within 30 mins ￫ Fresh linen, towels, toiletries & essentials provided. ￫ Fully equipped kitchen. ￫ Professionally cleaned every time. ￫ FREE unlimited 50Mbs Fibre WiFi, TV with Netflix. ￫ FREE  Tea, Instant Coffee and Sugar. The house will be entirely yours to use during the stay. Easy Self Check-in anytime after 3 PM, as late as you wish to. Unlimited 50Mbps Fibre-Optic Internet (Wifi + Ethernet). Its less than 100 meters away (2-3 min walk) from Cyprus DLR Train station. Excel by train takes 5 mins and O2 by train takes 15 mins and westminster/or any central london location takes 25 mins. On the ground floor: Kitchen + Dining Room + Open plan living room + Toilet with Shower + Back garden. On the first floor: Three    0.000013
# ﾛﾝﾄﾞﾝ市内の西部(ｾﾝﾄﾗﾙ線､ｼｪﾊﾟｰｽﾞ･ﾌﾞｯｼｭ駅より徒歩2分､ｿﾞｰﾝ2)に位置する静かで清潔､小さな庭付きのお家で､ﾌﾗﾝｽ人の主人と暮らしています｡ｵｯｸｽﾌｫｰﾄﾞ･ｻｰｶｽ駅､ﾋﾟｶﾃﾞﾘｰ･ｻｰｶｽ駅まで地下鉄で約15-20分と便利で､家から徒歩5分には､大型ｼｮｯﾋﾟﾝｸﾞｾﾝﾀｰのｳｪｽﾄﾌｨｰﾙﾄﾞ､高級ｽｰﾊﾟｰのｳｪｲﾄﾛｰｽﾞ､ｼｪﾊﾟｰｽﾞﾌﾞｯｼｭﾏｰｹｯﾄ､ﾚｽﾄﾗﾝやｶﾌｪ等もあります｡ 小さなｼﾝｸﾞﾙﾙｰﾑで､ﾊﾞｽﾙｰﾑ､ｷｯﾁﾝ､ﾀﾞｲﾆﾝｸﾞﾙｰﾑは共用になります｡ その他､ご質問ございましたら､お気軽にお問い合わせ下さいませ｡ 鍵付きのﾌﾟﾗｲﾍﾞｰﾄｹﾞｰﾄを入ると玄関前には小さな庭があり､1階にｷｯﾁﾝとﾀﾞｲﾆﾝｸﾞﾙｰﾑ､家の裏にも小さな庭があります｡2階は､寝室とﾊﾞｽﾙｰﾑがあります｡ お部屋は､小さなｼﾝｸﾞﾙﾙｰﾑにｼﾝｸﾞﾙﾍﾞｯﾄ､ｸﾛｰｾﾞｯﾄ､簡易机と椅子付きです｡ ｷｯﾁﾝ(ｶﾞｽｺﾝﾛ､ｶﾞｽｵｰﾌﾞﾝ､電子ﾚﾝｼﾞ､ｹﾄﾙ､冷蔵庫､冷凍庫､食器類)､ﾘﾋﾞﾝｸﾞﾙｰﾑ､ﾊﾞｽﾙｰﾑ､洗濯機､ｶﾞｰﾃﾞﾝ Central線Shepherds Bush駅より徒歩2分で､大型ｼｮｯﾋﾟﾝｸﾞｾﾝﾀｰのｳｪｽﾄﾌｨｰﾙﾄﾞ､高級ｽｰﾊﾟｰのｳｪｲﾄﾛｰｽﾞ､ｼｪﾊﾟｰｽﾞﾌﾞｯｼｭﾏｰｹｯﾄ､ﾚｽﾄﾗﾝやｶﾌｪ等も徒歩5分にあります｡家の近くには､毎週日曜日の午前中､無料でﾖｶﾞのﾚｯｽﾝが受けられます｡ Central線(Shepherds Bush駅)徒歩2分､ DLR線(Shepherds Bush駅)徒歩2分､ Hammersmith&City線(Shepherds Bush Market駅)徒歩5分 ﾋｰｽﾛｰ空港までは､地下鉄で約50分です｡ ｶﾞﾄｳｨｯｸ空港までは､電車で約1時間です｡                                                                                                                                                                                                         0.000013
# Name: id, Length: 72877, dtype: float64
#
# experiences_offered
# business    0.008487
# family      0.007448
# none        0.974398
# romantic    0.003166
# social      0.006501
# Name: id, dtype: float64
#
# neighborhood_overview
#  AREA Dulwich is one of London's finest 'villages', combining close proximity to the centre of the city with the peaceful ambience of a small and leafy country town.  Dulwich is only some 5 miles from Central London with superb public transport access, and is well known for its excellent private and state schools.  The name Dilwihs (Dulwich), meaning "Marshy Meadow Where Dill Grows," was first recorded in AD 967. The manor of Dulwich was owned by Bermondsey Abbey from (phone number hidden). Edward Alleyn, a successful Shakespearean actor, bought the manor in (Phone number hidden by Airbnb) and founded the "College of God's Gift" to provide education for "12 poor scholars" and almshouses for "6 poor brethren and 6 poor sisters." The Alleyn Foundation, reconstituted in (Phone number hidden by Airbnb) and again in (Phone number hidden by Airbnb) , now comprises three schools: Dulwich College, Alleyn's School, and James Allen's Girls' School. The main buildings of Dulwich College were buil    0.000013
#  Brixton is one of the best places in London. Good clubs, good people and there is also our lovely Brixton Market that there is where Im actually work part-time as a chef in a Japanese Restaurant. You can smoke but in the Kitchen                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.000013
#  Broadway Market (location of a brilliant, famous Saturday market and home to loads of bars cafes and boutiques) is a 5 minute walk away, London Fields (a huge green park) a 2 minute walk. Dalston (brilliant restaurants, shops aplenty) is a 5 minute walk away.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.000013
#  Bronnley Court is situated in an extremely safe and residential part of Acton, with a police station, fire station and clinic within sight of the flat. It offers guests a truly calm and relaxing respite after a full day of sight-seeing or business. There is even an authentic Thai massage spa downstairs to help you properly unwind.  A prestigious W3 postcode means it is ideally located in the rich and highly desirable area of West London for all your shopping and sightseeing needs. The apartment also benefits from some of the best transport connections across London, meaning all the popular tourist hot-spots are readily accessible.  Acton Town tube station is just a couple of minutes (4 tube stops) on the Piccadilly line away from South Kensington and the sprawling and beautiful Hyde Park, the world famous Royal Albert Hall, as well as the Natural History Museum, Science Museum and Victoria & Albert Museum. One more stop down the line will bring you to Knightsbridge and all the shoppin    0.000013
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.000013
# 개인 열쇠 드립니다. (단, 열쇠 보증금 £20)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.000013
# ...
# Dome house                       0.000039
# Earth house                      0.000117
# Farm stay                        0.000052
# Guest suite                      0.003841
# Guesthouse                       0.003166
# Hostel                           0.002530
# Hotel                            0.001531
# House                            0.202847
# Houseboat                        0.000260
# Hut                              0.000117
# Igloo                            0.000013
# In-law                           0.000013
# Island                           0.000013
# Lighthouse                       0.000013
# Loft                             0.009512
# Nature lodge                     0.000052
# Other                            0.002946
# Parking Space                    0.000026
# Resort                           0.000013
# Ryokan (Japan)                   0.000013
# Serviced apartment               0.027406
# Shepherd's hut (U.K., France)    0.000026
# Tent                             0.000013
# Tiny house                       0.000285
# Townhouse                        0.038021
# Treehouse                        0.000026
# Villa                            0.000532
# Yurt                             0.000052
# Name: id, dtype: float64
#
# room_type
# Entire home/apt    0.554598
# Private room       0.435760
# Shared room        0.009641
# Name: id, dtype: float64
#
# bed_type
# Airbed           0.000766
# Couch            0.000960
# Futon            0.002777
# Pull-out Sofa    0.006151
# Real Bed         0.989346
# Name: id, dtype: float64
#
# amenities
# {"Air conditioning","Free parking on premises","Free street parking",Heating,"Family/kid friendly","Suitable for events","First aid kit","Fire extinguisher",Essentials,"Lock on bedroom door","Host greets you"}                                                                                                  0.000013
# {"Air conditioning","Wheelchair accessible",Kitchen,Doorman,Breakfast,Elevator,"Buzzer/wireless intercom",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","First aid kit","Fire extinguisher",Essentials,Shampoo,Hangers,Iron,"Laptop friendly workspace","Private living room","Private entrance"}    0.000013
# {"Air conditioning","Wheelchair accessible",Kitchen,Doorman,Gym,Elevator,"Hot tub","Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,"Smoke detector","Carbon monoxide detector","First aid kit","Safety card","Fire extinguisher","Laptop friendly workspace"}                                         0.000013
# {"Air conditioning","Wheelchair accessible",Pool,Kitchen,Doorman,Gym,Elevator,"Buzzer/wireless intercom",Heating,Washer,Dryer,"Smoke detector",Essentials,Hangers,Iron,"Laptop friendly workspace"}                                                                                                                0.000013
# {"Air conditioning",Doorman,Breakfast,Elevator,"First aid kit",Essentials}                                                                                                                                                                                                                                         0.000013
#                                                                                                                                                                                                                                                                                                                      ...
# {Wifi,Washer,Dryer,Essentials}                                                                                                                                                                                                                                                                                     0.000013
# {Wifi,Washer,Essentials,Hangers,"Hair dryer"}                                                                                                                                                                                                                                                                      0.000013
# {Wifi,Washer}                                                                                                                                                                                                                                                                                                      0.000013
# {Wifi}                                                                                                                                                                                                                                                                                                             0.000104
# {}                                                                                                                                                                                                                                                                                                                 0.005268
# Name: id, Length: 68854, dtype: float64
#
# security_deposit
# $0.00        0.195606
# $1,000.00    0.013262
# $1,020.00    0.000013
# $1,045.00    0.000013
# $1,050.00    0.000013
# $1,074.00    0.000013
# $1,081.00    0.000013
# $1,100.00    0.000065
# $1,150.00    0.000013
# $1,176.00    0.000026
# $1,200.00    0.000389
# $1,250.00    0.000117
# $1,300.00    0.000065
# $1,336.00    0.000013
# $1,350.00    0.000013
# 43 months ago    0.001064
# 44 months ago    0.000597
# 45 months ago    0.000584
# 46 months ago    0.000519
# 47 months ago    0.000415
# 48 months ago    0.000441
# 49 months ago    0.000506
# 5 days ago       0.017233
# 5 months ago     0.022501
# 5 weeks ago      0.023915
# 50 months ago    0.000260
# 51 months ago    0.000130
# 52 months ago    0.000078
# 53 months ago    0.000169
# 54 months ago    0.000260
# 55 months ago    0.000104
# 56 months ago    0.000039
# 57 months ago    0.000052
# 58 months ago    0.000039
# 59 months ago    0.000130
# 6 days ago       0.005281
# 6 months ago     0.015533
# 6 weeks ago      0.019023
# 60 months ago    0.000039
# 61 months ago    0.000013
# 64 months ago    0.000039
# 66 months ago    0.000026
# 67 months ago    0.000039
# 68 months ago    0.000013
# 7 months ago     0.012782
# 7 weeks ago      0.010148
# 71 months ago    0.000026
# 73 months ago    0.000039
# 74 months ago    0.000026
# 76 months ago    0.000039
# 77 months ago    0.000026
# 78 months ago    0.000117
# 79 months ago    0.000091
# 8 months ago     0.011354
# 80 months ago    0.000169
# 81 months ago    0.000078
# 82 months ago    0.000078
# 83 months ago    0.000026
# 84 months ago    0.000026
# 9 months ago     0.011925
# a week ago       0.052334
# never            0.004464
# today            0.244359
# yesterday        0.044872
# Name: id, dtype: float64
#
# has_availability
# t    1.0
# Name: id, dtype: float64
#
# instant_bookable
# f    0.606556
# t    0.393444
# Name: id, dtype: float64
# cancellation_policy
# flexible                       0.327381
# moderate                       0.239427
# strict                         0.000078
# strict_14_with_grace_period    0.421966
# super_strict_30                0.006242
# super_strict_60                0.004905
# Name: id, dtype: float64

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 1. Separate dataset into train and test
#
# This is to avoid over-fitting. This step involves randomness, therefore, it's needed to set the seed.

# %%
# Let's separate into train and test set
# Remember to set the seed (random_state for this sklearn function)

X_train, X_test, y_train, y_test = train_test_split(df, df.price,test_size=0.1,random_state=0) # we are setting the seed here
X_train.shape, X_test.shape
# Out:
# ((69356, 72), (7707, 72))

# %%
X_train.head()
# Out:
#              id                                            summary                                              space                                        description experiences_offered                              neighborhood_overview                                              notes                                            transit                                             access host_name  host_since                     host_location  \
# 60730  26581320  Based in high quality student accommodation, o...  What To Expect: * Great 13 sqm room with moder...  Based in high quality student accommodation, o...                none  Everybody is after a slice of Tottenham these ...  • Do you have free WiFi? Yes we have super fas...  Tottenham Hale Station provides both National ...  You will enjoy your own private room with an e...   Natasha  2018-07-03                                GB
# 67037  28323093  Located in E2 the house is 5-7 min walk to Bet...  The house comprises of 5 bedrooms, large fully...  Located in E2 the house is 5-7 min walk to Bet...                none  A must have property with very superb location...                                                NaN                                                NaN                                                NaN  IRoom-UK  2013-08-28            London, United Kingdom
# 76987  30575629   My place is a very homely two bedroom apartment.                                                NaN   My place is a very homely two bedroom apartment.                none                                                NaN                                                NaN                                                NaN                                                NaN  Krasimir  2017-05-07                                GB
# 40630  20313438  Modern and newly renovated apartment. Gives yo...                                                NaN  Modern and newly renovated apartment. Gives yo...                none                                                NaN                                                NaN                                                NaN                                                NaN     Jamie  2017-08-08           England, United Kingdom
# 60204  26395171  This studio flat is brilliant for visiting the...                                                NaN  This studio flat is brilliant for visiting the...                none                                                NaN                                                NaN                                                NaN       The guest has access to the entire apartment      Rory  2014-11-18  Everdon, England, United Kingdom
#
#                                               host_about  host_response_time host_response_rate  host_acceptance_rate host_is_superhost host_neighbourhood  host_listings_count  host_total_listings_count                                 host_verifications host_identity_verified                                   street   neighbourhood  neighbourhood_cleansed  neighbourhood_group_cleansed            city    state   zipcode  market                  smart_location country_code         country  \
# 60730  Hey Airbnb'ers!\r\n\r\nI'm Natasha and I work ...                 NaN                NaN                   NaN                 t                NaN                 35.0                       35.0                                          ['email']                      f  Greater London, England, United Kingdom  LB of Haringey                Haringey                           NaN  Greater London  England   N17 9NE  London  Greater London, United Kingdom           GB  United Kingdom
# 67037  Who we are?\r\n\r\nWe are young company who br...                 NaN                NaN                   NaN                 f       LB of Newham                  6.0                        6.0  ['email', 'phone', 'reviews', 'jumio', 'govern...                      t  Greater London, England, United Kingdom      Globe Town           Tower Hamlets                           NaN  Greater London  England    E2 9PW  London  Greater London, United Kingdom           GB  United Kingdom
# 76987                                                NaN  within a few hours               100%                   NaN                 f      Covent Garden                 10.0                       10.0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                      f  Greater London, England, United Kingdom       Fitzrovia             Westminster                           NaN  Greater London  England       W1W  London  Greater London, United Kingdom           GB  United Kingdom
# 40630                                                NaN        within a day               100%                   NaN                 f             Fulham                  1.0                        1.0                                 ['email', 'phone']                      f  Greater London, England, United Kingdom             NaN  Hammersmith and Fulham                           NaN  Greater London  England   SW6 4AA  London  Greater London, United Kingdom           GB  United Kingdom
# 60204                 Keen traveller and welcoming host       within an hour               100%                   NaN                 f                NaN                  1.0                        1.0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                      t          London, England, United Kingdom         Pimlico             Westminster                           NaN          London  England  SW1V 2QT  London          London, United Kingdom           GB  United Kingdom
#
#         latitude  longitude is_location_exact       property_type        room_type  accommodates  bathrooms  bedrooms  beds  bed_type                                          amenities  square_feet   price  weekly_price  monthly_price security_deposit  cleaning_fee  guests_included  extra_people  minimum_nights  maximum_nights calendar_updated has_availability  availability_30  availability_60  availability_90  availability_365  number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 60730  51.588778  -0.057334                 f  Serviced apartment  Entire home/apt             2        1.0       1.0   1.0  Real Bed  {Wifi,Kitchen,Elevator,Heating,Washer,Dryer,"S...          NaN    55.0           NaN            NaN           $76.00          35.0                1           0.0               1            1125      5 weeks ago                t                0                0                0                 0                  2                 100.0                    10.0
# 67037  51.530209  -0.049470                 f               House     Private room             1        1.5       1.0   1.0  Real Bed  {Wifi,Kitchen,"Smoke detector","Fire extinguis...          NaN    30.0           NaN            NaN           $85.00          20.0                1           5.0               3            1125       1 week ago                t                0               14               14                14                  0                   NaN                     NaN
# 76987  51.517702  -0.138022                 f           Apartment  Entire home/apt             4        2.0       2.0   2.0  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN  1000.0           NaN            NaN          $500.00         150.0                2          15.0               2            1125            today                t               21               51               81               126                  0                   NaN                     NaN
# 40630  51.478065  -0.191610                 t           Apartment  Entire home/apt             4        1.0       2.0   2.0  Real Bed  {TV,Kitchen,Breakfast,"Indoor fireplace",Heati...          NaN   101.0           NaN            NaN          $200.00          30.0                1           0.0               2            1125       4 days ago                t                0                4               34               124                  0                   NaN                     NaN
# 60204  51.489238  -0.132231                 f           Apartment  Entire home/apt             2        1.0       0.0   1.0  Real Bed  {TV,Wifi,Kitchen,Elevator,"Buzzer/wireless int...          NaN   110.0           NaN            NaN              NaN          40.0                2          50.0               2            1125      4 weeks ago                t               13               13               13                13                 14                  94.0                    10.0
#
#        review_scores_cleanliness  review_scores_checkin  review_scores_communication  review_scores_location  review_scores_value instant_bookable          cancellation_policy  calculated_host_listings_count  reviews_per_month
# 60730                       10.0                   10.0                         10.0                    10.0                 10.0                f                     flexible                              35               0.45
# 67037                        NaN                    NaN                          NaN                     NaN                  NaN                f  strict_14_with_grace_period                               3                NaN
# 76987                        NaN                    NaN                          NaN                     NaN                  NaN                t  strict_14_with_grace_period                              10                NaN
# 40630                        NaN                    NaN                          NaN                     NaN                  NaN                f                     moderate                               1                NaN
# 60204                        9.0                    9.0                         10.0                    10.0                  9.0                t                     moderate                               1               2.71

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 2. Handling missing values

# %% [markdown]
# ### 2.1. Categorical variables
#
# For categorical variables, fill missing information by adding an additional category: "missing"

# %%
# make a list of the categorical variables that contain missing values
categorical_list = [var for var in df.columns if df[var].dtypes=='O']
missing_df = Check_Missing_Data(df[categorical_list])
missing_df.head()
# Out:
#                        Total   Percent
# notes                  46730  0.606387
# access                 32724  0.424640
# host_about             31948  0.414570
# neighborhood_overview  30180  0.391628
# transit                30072  0.390226

# %%
missing_df = missing_df.loc[missing_df.Percent < 0.3,]
missing_df.shape
categorical_list = missing_df.index.values
len(categorical_list)
# Out:
# 29

# %%
# function to replace NA in categorical variables
def fill_categorical_na(df, var_list):
    X = df.copy()
    X[var_list] = df[var_list].fillna('Missing')
    return X
                                      
# replace missing values with new label: "Missing"
X_train = fill_categorical_na(X_train, categorical_list)
# check that we have no missing information in the engineered variables
[var for var in missing_df.index.values if X_train[var].isnull().sum()>0]
# Out:
# []

# %%
# replace missing values with new label: "Missing"
X_test = fill_categorical_na(X_test, missing_df.index.values)
# check that we have no missing information in the engineered variables
[var for var in missing_df.index.values if X_test[var].isnull().sum()>0]
# Out:
# []

# %% [markdown]
# ### 2.2. Numerical variables

# %% [markdown]
# For numerical variables, add an additional variable to capture the missing information, and then replace the missing information in the original variable by the mode, or most frequent value:

# %%
removed_list = ['id','price']
# make a list of the categorical variables that contain missing values
numerical_list = [var for var in df.columns if df[var].dtypes!='O' and var not in removed_list]

# alternative approach
# numerics= ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
# numdf = df.select_dtypes(include=numerics)
# numerical_list = numdf.columns
# numerical_list

missing_df = Check_Missing_Data(df[numerical_list])
missing_df.shape
# Out:
# (32, 2)

# %%
missing_df = missing_df.loc[missing_df.Percent < 0.3,]
missing_df.shape
numerical_list = missing_df.index.values
len(numerical_list)
# Out:
# 27

# %%
# function to replace NA in categorical variables
def fill_numerical_na(df, var_list):
    X = df.copy()
    for var in var_list:
        # calculate the mode
        mode_val = X[var].mode()[0]
        X[var].fillna(mode_val, inplace=True)
    return X

# %%
# replace mode the missing values
X_train = fill_numerical_na(X_train, numerical_list)
# check that we have no missing information in the engineered variables
[var for var in missing_df.index.values if X_train[var].isnull().sum()>0]
# Out:
# []

# %%
# replace mode the missing values
X_test = fill_numerical_na(X_test, missing_df.index.values)
# check that we have no missing information in the engineered variables
[var for var in missing_df.index.values if X_test[var].isnull().sum()>0]
# Out:
# []

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## 4. Numerical variables

# %% [markdown]
# ### 4.1. Log Transform Non-Gaussian distributed variables
#
# We will log transform the numerical variables that do not contain zeros in order to get a more Gaussian-like distribution. This tends to help Linear machine learning models.

# %%
X_train['log_price'] = np.log(X_train['price'])
X_test['log_price'] = np.log(X_test['price'])
#for var in ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']:
#    X_train[var] = np.log(X_train[var])
#    X_test[var]= np.log(X_test[var])

# %% [markdown]
# ## 5. Categorical variables

# %%
categorical_list = []
def analyse_frequency_labels(df, var):
    df = df.copy()
    tmp = df.groupby(var)['SalePrice'].count() / len(df)
    return tmp

for var in categorical_list:
    print(analyse_frequency_labels(X_train, var))
    print()

# %%
cat_df = pd.DataFrame()
full_ds = pd.concat(objs=[X_train[categorical_list], X_test[categorical_list]], axis=0)
for var in categorical_list:
    var_dummies = pd.get_dummies(full_ds[var], prefix=var, prefix_sep='_',drop_first=True)
    cat_df = pd.concat([cat_df, var_dummies], axis=1)
    
l = X_train.shape[0]
train_cat_df = cat_df[:l].reset_index(drop=True)
test_cat_df = cat_df[l:].reset_index(drop=True)

# %% [markdown]
# ### selected features

# %%
selected_features = numerical_list
selected_features
# Out:
# array(['cleaning_fee', 'review_scores_value', 'review_scores_location',
#        'review_scores_checkin', 'review_scores_accuracy',
#        'review_scores_communication', 'review_scores_cleanliness',
#        'review_scores_rating', 'reviews_per_month', 'bathrooms', 'beds',
#        'bedrooms', 'host_listings_count', 'host_total_listings_count',
#        'number_of_reviews', 'latitude', 'longitude', 'accommodates',
#        'maximum_nights', 'minimum_nights', 'availability_365',
#        'availability_90', 'availability_60', 'availability_30',
#        'guests_included', 'calculated_host_listings_count',
#        'extra_people'], dtype=object)

# %%
[var for var in selected_features if X_train[var].isnull().sum()>0]
# Out:
# []

# %%
[var for var in selected_features if X_test[var].isnull().sum()>0]
# Out:
# []

# %% [markdown]
# # Feature Scaling

# %%
# fit scaler
scaler = MinMaxScaler() # create an instance
scaler.fit(X_train[selected_features]) #  fit  the scaler to the train set for later use

# transform the train and test set, and add on the Id and SalePrice variables
train_num_df = pd.DataFrame(scaler.transform(X_train[selected_features]), columns=selected_features)
test_num_df = pd.DataFrame(scaler.transform(X_test[selected_features]), columns=selected_features)

# %%
train_num_df.head()
# Out:
#    cleaning_fee  review_scores_value  review_scores_location  review_scores_checkin  review_scores_accuracy  review_scores_communication  review_scores_cleanliness  review_scores_rating  reviews_per_month  bathrooms      beds  bedrooms  host_listings_count  host_total_listings_count  number_of_reviews  latitude  longitude  accommodates  maximum_nights  minimum_nights  availability_365  availability_90  availability_60  availability_30  guests_included  calculated_host_listings_count  \
# 0      0.057003                1.000                     1.0                  1.000                     1.0                          1.0                      1.000                 1.000           0.026586   0.071429  0.043478  0.022727             0.023585                   0.023585           0.003460  0.759846   0.564347      0.052632    5.234033e-07        0.000000          0.000000         0.000000         0.000000         0.000000         0.000000                        0.031336
# 1      0.032573                1.000                     1.0                  1.000                     1.0                          1.0                      1.000                 1.000           0.059819   0.107143  0.043478  0.022727             0.004043                   0.004043           0.000000  0.608466   0.574343      0.000000    5.234033e-07        0.001779          0.038356         0.155556         0.233333         0.000000         0.000000                        0.001843
# 2      0.244300                1.000                     1.0                  1.000                     1.0                          1.0                      1.000                 1.000           0.059819   0.142857  0.086957  0.045455             0.006739                   0.006739           0.000000  0.576140   0.461781      0.157895    5.234033e-07        0.000890          0.345205         0.900000         0.850000         0.700000         0.043478                        0.008295
# 3      0.048860                1.000                     1.0                  1.000                     1.0                          1.0                      1.000                 1.000           0.059819   0.071429  0.086957  0.045455             0.000674                   0.000674           0.000000  0.473692   0.393664      0.157895    5.234033e-07        0.000890          0.339726         0.377778         0.066667         0.000000         0.000000                        0.000000
# 4      0.065147                0.875                     1.0                  0.875                     1.0                          1.0                      0.875                 0.925           0.163142   0.071429  0.043478  0.000000             0.000674                   0.000674           0.024221  0.502570   0.469141      0.052632    5.234033e-07        0.000890          0.035616         0.144444         0.216667         0.433333         0.043478                        0.000000
#
#    extra_people
# 0      0.000000
# 1      0.021277
# 2      0.063830
# 3      0.000000
# 4      0.212766

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Save preprocessed dataset

# %%
train_ds = pd.concat([pd.DataFrame(X_train[['id']]).reset_index(drop=True),train_num_df,train_cat_df,pd.DataFrame(X_train['log_price']).reset_index(drop=True)],axis = 1)
train_ds.to_csv('preprocessed_train_01.csv',index=False)
test_ds = pd.concat([pd.DataFrame(X_test[['id']]).reset_index(drop=True),test_num_df,test_cat_df,pd.DataFrame(X_test['log_price']).reset_index(drop=True)],axis = 1)
test_ds.to_csv('preprocessed_test_01.csv',index=False)

# %%
# now we save the selected list of features
pd.Series(train_ds.columns).to_csv('selected_features.csv', index=False)

# %%
pd.Series(train_num_df.columns)
# Out:
# 0                       cleaning_fee
# 1                review_scores_value
# 2             review_scores_location
# 3              review_scores_checkin
# 4             review_scores_accuracy
# 5        review_scores_communication
# 6          review_scores_cleanliness
# 7               review_scores_rating
# 8                  reviews_per_month
# 9                          bathrooms
# 10                              beds
# 11                          bedrooms
# 12               host_listings_count
# 13         host_total_listings_count
# 14                 number_of_reviews
# 15                          latitude
# 16                         longitude
# 17                      accommodates
# 18                    maximum_nights
# 19                    minimum_nights
# 20                  availability_365
# 21                   availability_90
# 22                   availability_60
# 23                   availability_30
# 24                   guests_included
# 25    calculated_host_listings_count
# 26                      extra_people
# dtype: object
